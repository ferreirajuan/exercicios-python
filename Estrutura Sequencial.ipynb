# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
n = int(input("Informe um numero: "))
print(f"O numero informado foi {n}")
# Out:
# O numero informado foi 1

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
n1 = int(input("Informe um número: "))
n2 = int(input("Informe um número: "))
soma = n1 + n2
print(f"A soma dos dois numeros é de {soma}")
# Out:
# A soma dos dois numero é de 3

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
n1 = int(input("Informe uma nota: "))
n2 = int(input("Informe uma nota: "))
n3 = int(input("Informe uma nota: "))
n4 = int(input("Informe uma nota: "))
soma = n1 + n2 + n3 + n4
media = soma/4

print(F"A média é de {media}")
# Out:
# A média é de 10.0

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metro = float(input("Informe o metro"))
#type(metro)
cm = metro * 100
print(f"O valor de {metro}M convetido em CM é de {cm}")
# Out:
# O valor de 1.8M convetido em CM é de 180.0

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = int(input("Informe a largura: "))
comprimento = int(input("Informe o comprimento: "))

area = largura * comprimento

print(f"A area da sala é de {area}m ")
# Out:
# A area da sala é de 400m

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
valor_hora = float(input("Informe o valor das suas horas trabalhadas"))
numero_hora = int(input(f"Informe o seu total de horas trabalhadas"))
salario = 156 * 56

print(f"O seu salário é de {salario}")
# Out:
# O seu salário é de 8736

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
F = float(input("Informe a temperatura em Fahrenheit: "))
C = 5/9*(F-32)
print(f"A temperaturea em Celsius é de {C}")
# Out:
# A temperaturea em Celsius é de 512.2222222222223

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
C = float(input("Informe a temperatura em Celsius: "))
F = 9/5 * C + 32
print(f"A temperaturea em Fahrenheit é de {F}")
# Out:
# A temperaturea em Fahrenheit é de 908.6

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
h = float(input("Informe a sua altura: "))
p = 72,.7 * h - 58
print(p)
# Out:
# (72, 348.0)

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
escolha = input("Você é homem ou mulher: ")

if(escolha == h):
    altura = float(input("Informe sua altura: "))
    p = 72.7 * altura - 58
    print(p)
else:
    altura = float(input("Informe sua altura: "))
    p = 62.1 * altura - 44.7
    print(p)
# Out:
# 57.765

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
valor_hora = float(input("Informe o valor das suas horas trabalhadas"))
numero_hora = int(input(f"Informe o seu total de horas trabalhadas"))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario = valor_hora * numero_hora
print(f"O seu salário bruto é de {salario}")
# Out:
# O seu salário bruto é de 1000.0

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
desconto = (11 / 100) * salario
salario_desc = salario - desconto
print(f"Seu salário com desconto é de {salario_desc}")
# Out:
# Seu salário com desconto é de 890.0

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
desconto_inss = (8 / 100) * salario
salario_desc = salario - desconto_inss
print(f"Seu salário com desconto é de {salario_desc}")
# Out:
# Seu salário com desconto é de 920.0

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
desconto_sind= (5 / 100) * salario
salario_desc = salario - desconto_sind
print(f"Seu salário com desconto é de {salario_desc}")
# Out:
# Seu salário com desconto é de 950.0

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_liquido = salario - desconto_inss - desconto - desconto_sind

print(f"Seu salário com desconto é de {salario_liquido}")
# Out:
# Seu salário com desconto é de 760.0

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area = float(input("Informe em metros o tamanho da área: "))

qnt_tinta = area / 3

qnt_latas = qnt_tinta / 18

preco = qnt_latas * 80

print(f"Quantidade de latas de tinta a serem compradas: {qnt_latas:.2f}")
print(f"Preço total: R$ {preco:.2f}")
# Out:
# 6.666666666666667
# Quantidade de latas de tinta a serem compradas: 0.37
# Preço total: R$ 29.63

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
arquivo = float(input("Informe o tamanho do arquivo: "))
internet = float(input("Informe a velocidade da sua internet: "))
resultado = arquivo / internet
print(f"O tempo aproximado de download é de {resultado}")
# Out:
# O tempo aproximado de download é de 6.666666666666667
